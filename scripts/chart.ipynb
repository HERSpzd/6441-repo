# %%
# This script is to generate some charts for report 4.Experimental Evaluation and Results

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
content = {
    'Stage 1 (Manual) SR': [12.5, 15.0, 18.2, 100],
    'Stage 1 (Autumatic) LR': [25.0, 22.1, 28.5, 100],
    'Stage 2 (Manual) SR': [30.2, 35.5, 25.0, None],
    'Stage 2 (Autumatic) LR': [45.1, 40.0, 50.8, None]
}

df = pd.DataFrame(content, index=['Local LLM', 'Web free LLM', 'Web paid LLM', 'Uncensored LLM'])

colors = ['#4C72B0', '#DD8452', '#55A868', '#C44E52']

df.plot(kind='bar', figsize=(10, 5))


plt.ylabel('SR/LR (%)')
plt.xticks(rotation=0)

plt.figtext(0.12, 0.01, "Note: The data from Unsensored LLM Stage 2 does not need to be tested because it is already an LLM without safety guard, which has been validated in Stage 1", fontsize=10, color='gray')

plt.show()
